# %%
# Out:
# ...
# 100%|██████████| 172k/172k [00:00<00:00, 190kB/s]
# Extracting files...
# Path to dataset files: C:\Users\Admin\.cache\kagglehub\datasets\blastchar\telco-customer-churn\versions\1
